# %%
import pandas as pd
import numpy as np
import scipy as sp
import tournamentGameByGameCleaning as tGGC

# %%
tournamentGameByGame = tGGC.getTournamentGameByGame()
tournamentGameByGame.describe()
# Out:
#             index         Year       Seed1       Seed2       Round  \
# count  441.000000   441.000000  441.000000  441.000000  441.000000
# mean    62.000000  2016.000000    4.784580    8.777778    0.904762
# std     36.409789     2.002271    3.220155    4.795884    1.192781
# min      0.000000  2013.000000    1.000000    1.000000    0.000000
# 25%     30.000000  2014.000000    2.000000    4.000000    0.000000
# 50%     62.000000  2016.000000    5.000000    9.000000    0.000000
# 75%     94.000000  2018.000000    7.000000   13.000000    1.000000
# max    124.000000  2019.000000   16.000000   16.000000    5.000000
#
#            spread         id
# count  441.000000  441.00000
# mean     4.877551  220.00000
# std     14.052611  127.44999
# min    -29.000000    0.00000
# 25%     -4.000000  110.00000
# 50%      5.000000  220.00000
# 75%     14.000000  330.00000
# max     47.000000  440.00000

# %%
tournamentGameByGame
# Out:
#       index  Year       Team1  Seed1           Team2  Seed2  Round  spread  \
# 3150      0  2013     indiana      1   james madison     16      0      21
# 3152      2  2013    nc state      8          temple      9      0      -4
# 3154      4  2013        unlv      5      california     12      0      -3
# 3156      6  2013    syracuse      4         montana     13      0      47
# 3158      8  2013      butler      6        bucknell     11      0      12
# ...     ...   ...         ...    ...             ...    ...    ...     ...
# 4022    116  2019      purdue      3       tennessee      2      2       5
# 4024    118  2019    virginia      1          purdue      3      3       5
# 4026    120  2019    virginia      1          auburn      5      4       1
# 4028    122  2019  texas tech      3  michigan state      2      4      10
# 4030    124  2019    virginia      1      texas tech      3      5       8
#
#      winner   id
# 3150  Team1    0
# 3152  Team2    1
# 3154  Team2    2
# 3156  Team1    3
# 3158  Team1    4
# ...     ...  ...
# 4022  Team1  436
# 4024  Team1  437
# 4026  Team1  438
# 4028  Team1  439
# 4030  Team1  440
#
# [441 rows x 10 columns]

# %%
tournamentGameByGame = tournamentGameByGame.reset_index()

# %%
prevTournamentStats = pd.read_csv('March Madness Data/Historical Data/mdf.csv')
prevTournamentStats = prevTournamentStats.drop(['TEAM.1', 'ROUND', 'SEED'], axis=1)
prevTournamentStats
# Out:
#      YEAR                TEAM  KENPOM ADJUSTED EFFICIENCY  \
# 0    2019            virginia                        35.7
# 1    2019                duke                        32.0
# 2    2019             gonzaga                        32.8
# 3    2019      north carolina                        29.2
# 4    2019        michigan st.                        31.4
# ..    ...                 ...                         ...
# 471  2013  north carolina a&t                        -5.3
# 472  2013            southern                        -0.3
# 473  2013    western kentucky                        -1.0
# 474  2013             liberty                        -9.5
# 475  2013        liu brooklyn                        -1.4
#
#      KENPOM ADJUSTED OFFENSE  KENPOM ADJUSTED DEFENSE  KENPOM ADJUSTED TEMPO  \
# 0                      123.6                     87.9                   59.3
# 1                      120.1                     88.1                   72.2
# 2                      125.1                     92.3                   69.8
# 3                      119.9                     90.7                   74.3
# 4                      121.7                     90.4                   67.4
# ..                       ...                      ...                    ...
# 471                     92.6                     97.9                   64.8
# 472                     99.0                     99.3                   62.8
# 473                    101.8                    102.8                   63.8
# 474                    100.5                    110.0                   63.8
# 475                    111.1                    112.4                   66.7
#
#      BARTTORVIK ADJUSTED EFFICIENCY  BARTTORVIK ADJUSTED OFFENSE  \
# 0                              33.9                        122.6
# 1                              31.0                        119.3
# 2                              32.5                        124.1
# 3                              28.0                        119.2
# 4                              28.1                        120.0
# ..                              ...                          ...
# 471                            -5.2                         90.7
# 472                            -0.7                         96.3
# 473                            -1.3                         99.2
# 474                           -10.4                         97.9
# 475                            -3.2                        108.2
#
#      BARTTORVIK ADJUSTED DEFENSE  BARTHAG  ...  3PT RATE DEFENSE  OP ASSIST %  \
# 0                           88.7    0.976  ...              40.9         43.9
# 1                           88.3    0.970  ...              34.7         48.7
# 2                           91.6    0.971  ...              34.6         41.1
# 3                           91.2    0.956  ...              42.5         54.7
# 4                           91.9    0.956  ...              37.0         53.1
# ..                           ...      ...  ...               ...          ...
# 471                         95.9    0.345  ...              38.2         57.4
# 472                         97.0    0.479  ...              30.1         41.6
# 473                        100.5    0.463  ...              31.7         44.6
# 474                        108.3    0.239  ...              33.1         51.6
# 475                        111.4    0.417  ...              30.6         53.9
#
#      OP O REB %  OP D REB %  BLOCKED %  TURNOVER % DEFENSE  WINS ABOVE BUBBLE  \
# 0          25.9        70.0        8.4                17.8               11.1
# 1          29.7        63.9        8.0                19.8               11.2
# 2          27.1        69.4        4.9                18.9                7.1
# 3          23.2        65.4       11.1                18.5               10.0
# 4          26.8        65.9        8.3                14.9               10.6
# ..          ...         ...        ...                 ...                ...
# 471        33.4        69.8       11.2                23.6              -11.5
# 472        31.1        73.3        8.7                20.3               -5.7
# 473        31.1        65.2       10.8                20.7               -8.4
# 474        32.9        70.7       10.6                15.2              -15.6
# 475        33.3        65.0        9.5                18.4               -8.6
#
#      WIN %  POINTS PER POSSESSION OFFENSE  POINTS PER POSSESSION DEFENSE
# 0    90.63                          1.171                          0.898
# 1    85.29                          1.129                          0.913
# 2    90.91                          1.241                          0.909
# 3    81.82                          1.126                          0.955
# 4    82.35                          1.144                          0.951
# ..     ...                            ...                            ...
# 471  52.94                          0.920                          0.917
# 472  68.97                          1.019                          0.894
# 473  55.88                          0.998                          0.987
# 474  37.50                          1.009                          1.060
# 475  60.61                          1.122                          1.078
#
# [476 rows x 38 columns]

# %%
prevTournamentStats[((prevTournamentStats['TEAM'] == 'michigan state') & (prevTournamentStats['YEAR'] == 2019))]
# Out:
# Empty DataFrame
# Columns: [YEAR, TEAM, KENPOM ADJUSTED EFFICIENCY, KENPOM ADJUSTED OFFENSE, KENPOM ADJUSTED DEFENSE, KENPOM ADJUSTED TEMPO, BARTTORVIK ADJUSTED EFFICIENCY, BARTTORVIK ADJUSTED OFFENSE, BARTTORVIK ADJUSTED DEFENSE, BARTHAG, ELITE SOS, BARTTORVIK ADJUSTED TEMPO, 2PT %, 3PT %, FREE THROW %, EFG %, FREE THROW RATE, 3PT RATE, ASSIST %, OFFENSIVE REBOUND %, DEFENSIVE REBOUND %, BLOCK %, TURNOVER %, 2PT % DEFENSE, 3PT % DEFENSE, FREE THROW % DEFENSE, EFG % DEFENSE, FREE THROW RATE DEFENSE, 3PT RATE DEFENSE, OP ASSIST %, OP O REB %, OP D REB %, BLOCKED %, TURNOVER % DEFENSE, WINS ABOVE BUBBLE, WIN %, POINTS PER POSSESSION OFFENSE, POINTS PER POSSESSION DEFENSE]
# Index: []
#
# [0 rows x 38 columns]

# %%
# Out:
# 432

# %%
prevTournamentStats[prevTournamentStats['TEAM'] == 'michigan state']
# Out:
# Empty DataFrame
# Columns: [YEAR, TEAM, KENPOM ADJUSTED EFFICIENCY, KENPOM ADJUSTED OFFENSE, KENPOM ADJUSTED DEFENSE, KENPOM ADJUSTED TEMPO, BARTTORVIK ADJUSTED EFFICIENCY, BARTTORVIK ADJUSTED OFFENSE, BARTTORVIK ADJUSTED DEFENSE, BARTHAG, ELITE SOS, BARTTORVIK ADJUSTED TEMPO, 2PT %, 3PT %, FREE THROW %, EFG %, FREE THROW RATE, 3PT RATE, ASSIST %, OFFENSIVE REBOUND %, DEFENSIVE REBOUND %, BLOCK %, TURNOVER %, 2PT % DEFENSE, 3PT % DEFENSE, FREE THROW % DEFENSE, EFG % DEFENSE, FREE THROW RATE DEFENSE, 3PT RATE DEFENSE, OP ASSIST %, OP O REB %, OP D REB %, BLOCKED %, TURNOVER % DEFENSE, WINS ABOVE BUBBLE, WIN %, POINTS PER POSSESSION OFFENSE, POINTS PER POSSESSION DEFENSE]
# Index: []
#
# [0 rows x 38 columns]

# %%
#Adding Kenpom Adjusted Efficiency for each team


kenPomAdjEffTeam1 = [];
kenPomAdjEffTeam2 = [];


for i in range(0,len(tournamentGameByGame)):
    teamRowJacob = tournamentGameByGame[tournamentGameByGame['id'] == i]
    team1Name = teamRowJacob.Team1
    #print(team1Name[i])
    team2Name = teamRowJacob.Team2
    year = teamRowJacob.Year
    #print(year[i])
    team1RowJack = prevTournamentStats[((prevTournamentStats['TEAM'] == team1Name[i]) & (prevTournamentStats['YEAR'] == year[i]))]
    team2RowJack = prevTournamentStats[((prevTournamentStats['TEAM'] == team2Name[i]) & (prevTournamentStats['YEAR'] == year[i]))]
    #print()
    
    #team1RowJack = prevTournamentStats.loc(prevTournamentStats['TEAM'])
    kenPomAdjEffTeam1Val = team1RowJack['KENPOM ADJUSTED EFFICIENCY']
    kenPomAdjEffTeam2Val = team2RowJack['KENPOM ADJUSTED EFFICIENCY']
    if(kenPomAdjEffTeam1Val.empty):
        kenPomAdjEffTeam1.append(None)
    else:
        #print(kenPomAdjEffTeam1Val[team1RowJack.index[0]])
        #print('--------------------')
        kenPomAdjEffTeam1.append(kenPomAdjEffTeam1Val[team1RowJack.index[0]])
        
    if(kenPomAdjEffTeam2Val.empty):
        kenPomAdjEffTeam2.append(None)
    else:
        #print(team2Name[i])
        #print(kenPomAdjEffTeam2Val[team2RowJack.index[0]])
        #print('--------------------')
        kenPomAdjEffTeam2.append(kenPomAdjEffTeam2Val[team2RowJack.index[0]])
    
tournamentGameByGame['KENPOM ADJUSTED EFFICIENCY TEAM1'] = kenPomAdjEffTeam1
tournamentGameByGame['KENPOM ADJUSTED EFFICIENCY TEAM2'] = kenPomAdjEffTeam2

tournamentGameByGame
# Out:
#      level_0  index  Year       Team1  Seed1           Team2  Seed2  Round  \
# 0       3150      0  2013     indiana      1   james madison     16      0
# 1       3152      2  2013    nc state      8          temple      9      0
# 2       3154      4  2013        unlv      5      california     12      0
# 3       3156      6  2013    syracuse      4         montana     13      0
# 4       3158      8  2013      butler      6        bucknell     11      0
# ..       ...    ...   ...         ...    ...             ...    ...    ...
# 436     4022    116  2019      purdue      3       tennessee      2      2
# 437     4024    118  2019    virginia      1          purdue      3      3
# 438     4026    120  2019    virginia      1          auburn      5      4
# 439     4028    122  2019  texas tech      3  michigan state      2      4
# 440     4030    124  2019    virginia      1      texas tech      3      5
#
#      spread winner   id  KENPOM ADJUSTED EFFICIENCY TEAM1  \
# 0        21  Team1    0                              29.9
# 1        -4  Team2    1                               NaN
# 2        -3  Team2    2                              17.2
# 3        47  Team1    3                              22.6
# 4        12  Team1    4                              14.8
# ..      ...    ...  ...                               ...
# 436       5  Team1  436                              26.1
# 437       5  Team1  437                              35.7
# 438       1  Team1  438                              35.7
# 439      10  Team1  439                              26.7
# 440       8  Team1  440                              35.7
#
#      KENPOM ADJUSTED EFFICIENCY TEAM2
# 0                                -1.7
# 1                                12.0
# 2                                12.7
# 3                                 2.7
# 4                                13.4
# ..                                ...
# 436                              27.0
# 437                              26.1
# 438                              23.3
# 439                               NaN
# 440                              26.7
#
# [441 rows x 13 columns]

# %%
mismatchTeam1 = tournamentGameByGame[tournamentGameByGame['KENPOM ADJUSTED EFFICIENCY TEAM1'].isna()]
mismatchTeam2 = tournamentGameByGame[tournamentGameByGame['KENPOM ADJUSTED EFFICIENCY TEAM2'].isna()]
mismatch = []
for team in mismatchTeam1['Team1'].unique():
    mismatch.append(team)
for team in mismatchTeam2['Team2'].unique():
    mismatch.append(team)
mismatchTeam1['Team1'].unique()
#mismatchTeam2['Team2'].unique()
#mismatch = 'team1: ' + mismatchTeam1['Team1'] + ' team2: ' + mismatchTeam2['Team2']
mismatch = set(mismatch)
df = tournamentGameByGame[tournamentGameByGame[id] < 44]
df['Col'] = mismatch
df['Col'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 140586875932288
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-a41cbe278a62> in <module>
#      10 #mismatch = 'team1: ' + mismatchTeam1['Team1'] + ' team2: ' + mismatchTeam2['Team2']
#      11 mismatch = set(mismatch)
# ---> 12 df = tournamentGameByGame[tournamentGameByGame[id] < 44]
#      13 df['Col'] = mismatch
#      14 df['Col'].unique()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 140586875932288

# %%
#Generalizing adding stat columns for all stat columns

statTeam1 = [];
statTeam2 = [];

statColName = 'KENPOM ADJUSTED OFFENSE'


for i in range(0,len(tournamentGameByGame)):
    teamRowJacob = tournamentGameByGame[tournamentGameByGame['id'] == i]
    team1Name = teamRowJacob.Team1
    #print(team1Name[i])
    team2Name = teamRowJacob.Team2
    year = teamRowJacob.Year
    #print(year[i])
    team1RowJack = prevTournamentStats[((prevTournamentStats['TEAM'] == team1Name[i]) & (prevTournamentStats['YEAR'] == year[i]))]
    team2RowJack = prevTournamentStats[((prevTournamentStats['TEAM'] == team2Name[i]) & (prevTournamentStats['YEAR'] == year[i]))]
    #print()
    
    #team1RowJack = prevTournamentStats.loc(prevTournamentStats['TEAM'])
    statTeam1Val = team1RowJack[statColName]
    statTeam2Val = team2RowJack[statColName]
    if(statTeam1Val.empty):
        statTeam1.append(None)
    else:
        #print(kenPomAdjEffTeam1Val[team1RowJack.index[0]])
        #print('--------------------')
        statTeam1.append(statTeam1Val[team1RowJack.index[0]])
        
    if(statTeam2Val.empty):
        statTeam2.append(None)
    else:
        #print(team2Name[i])
        #print(kenPomAdjEffTeam2Val[team2RowJack.index[0]])
        #print('--------------------')
        statTeam2.append(statTeam2Val[team2RowJack.index[0]])
    
tournamentGameByGame[f'{statColName} Team1'] = statTeam1
tournamentGameByGame[f'{statColName} Team2'] = statTeam2

tournamentGameByGame
# Out:
#      level_0  index  Year       Team1  Seed1           Team2  Seed2  Round  \
# 0       3150      0  2013     indiana      1   james madison     16      0
# 1       3152      2  2013    nc state      8          temple      9      0
# 2       3154      4  2013        unlv      5      california     12      0
# 3       3156      6  2013    syracuse      4         montana     13      0
# 4       3158      8  2013      butler      6        bucknell     11      0
# ..       ...    ...   ...         ...    ...             ...    ...    ...
# 436     4022    116  2019      purdue      3       tennessee      2      2
# 437     4024    118  2019    virginia      1          purdue      3      3
# 438     4026    120  2019    virginia      1          auburn      5      4
# 439     4028    122  2019  texas tech      3  michigan state      2      4
# 440     4030    124  2019    virginia      1      texas tech      3      5
#
#      spread winner   id  KENPOM ADJUSTED EFFICIENCY TEAM1  \
# 0        21  Team1    0                              29.9
# 1        -4  Team2    1                               NaN
# 2        -3  Team2    2                              17.2
# 3        47  Team1    3                              22.6
# 4        12  Team1    4                              14.8
# ..      ...    ...  ...                               ...
# 436       5  Team1  436                              26.1
# 437       5  Team1  437                              35.7
# 438       1  Team1  438                              35.7
# 439      10  Team1  439                              26.7
# 440       8  Team1  440                              35.7
#
#      KENPOM ADJUSTED EFFICIENCY TEAM2  KENPOM ADJUSTED OFFENSE Team1  \
# 0                                -1.7                          122.5
# 1                                12.0                            NaN
# 2                                12.7                          106.9
# 3                                 2.7                          114.5
# 4                                13.4                          110.1
# ..                                ...                            ...
# 436                              27.0                          121.1
# 437                              26.1                          123.6
# 438                              23.3                          123.6
# 439                               NaN                          112.7
# 440                              26.7                          123.6
#
#      KENPOM ADJUSTED OFFENSE Team2
# 0                             99.6
# 1                            111.5
# 2                            107.4
# 3                            105.6
# 4                            107.9
# ..                             ...
# 436                          122.5
# 437                          121.1
# 438                          119.6
# 439                            NaN
# 440                          112.7
#
# [441 rows x 15 columns]

# %%
tournamentGameByGame.loc[(tournamentGameByGame['Team1'].str.contains(" st\.")) | (tournamentGameByGame['Team2'].str.contains(" st\."))]
# Out:
#      level_0  index  Year      Team1  Seed1             Team2  Seed2  Round  \
# 252     3654      0  2017  villanova      1  mount st. mary's     16      0
#
#      spread winner   id  KENPOM ADJUSTED EFFICIENCY TEAM1  \
# 252      20  Team1  252                              30.8
#
#      KENPOM ADJUSTED EFFICIENCY TEAM2  KENPOM ADJUSTED OFFENSE Team1  \
# 252                              -4.2                          122.8
#
#      KENPOM ADJUSTED OFFENSE Team2
# 252                           99.0
